// %% [markdown]
// # Lab 18 Exercise 3

// %% [markdown]
// ## Generic method

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab18_Ex03
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// // Generic method
// Generic.Show<int>("Integer", 123);
// Generic.Show<float>("Floating point", 123.45f);
// Generic.Show<decimal>("Decimal", 2345.67M);
// Generic.Show<string>("String", "Hello World");
//
//
// public static class Generic
// {
//     public static void Show <T> (string message, T value)
//     {
//         System.Console.WriteLine($"{message,-15} : {value}");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab18_Ex03
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![05.png](attachment:05.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab18_Ex03
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![06.png](attachment:06.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// ในการทดลองนี้มีการใช้ generic method ที่ชื่อว่า Show<T> ซึ่งช่วยให้สามารถแสดงค่าของข้อมูลประเภทต่างๆ ได้ในรูปแบบที่ยืดหยุ่น
//
// โดย T เป็นตัวแทนของชนิดข้อมูลที่เราต้องการใช้ในแต่ละครั้ง เช่น int, float, decimal, string
